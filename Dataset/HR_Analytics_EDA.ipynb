# %%
#CORRELATION HEATMAP#
plt.figure(figsize=(14,10))

sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Heatmap")
plt.show()

# %%
correlation_matrix = numeric_df.corr()

correlation_matrix
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
numeric_df = df.select_dtypes(include=["int64", "float64"])

numeric_df.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 0   41       1102                 1          2              1               1
# 1   49        279                 8          1              1               2
# 2   37       1373                 2          2              1               4
# 3   33       1392                 3          4              1               5
# 4   27        591                 2          1              1               7
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  ...  \
# 0                        2          94               3         2  ...
# 1                        3          61               2         2  ...
# 2                        4          92               2         1  ...
# 3                        4          56               3         1  ...
# 4                        1          40               3         1  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
#YEARS AT COMPANY WISE ATTRITION#
plt.figure(figsize=(9,5))

sns.countplot(
    data=df,
    x="YearsGroup",
    hue="Attrition"
)

plt.title("Employee Attrition by Years at Company", fontsize=14)
plt.xlabel("Years at Company")
plt.ylabel("Number of Employees")
plt.grid(axis="y", linestyle="--", alpha=0.5)

plt.show()

# %%
years_attrition = pd.crosstab(
    df["YearsGroup"],
    df["Attrition"],
    normalize="index"
) * 100

years_attrition = years_attrition.round(2)

years_attrition
# Out:
# Attrition       No    Yes
# YearsGroup
# 0-2 Years    71.14  28.86
# 3-5 Years    86.18  13.82
# 6-10 Years   87.72  12.28
# 11-20 Years  93.33   6.67
# 21+ Years    87.88  12.12

# %%
df["YearsGroup"] = pd.cut(
    df["YearsAtCompany"],
    bins=[0,2,5,10,20,40],
    labels=["0-2 Years","3-5 Years","6-10 Years","11-20 Years","21+ Years"]
)

df["YearsGroup"].value_counts().sort_index()
# Out:
# YearsGroup
# 0-2 Years      298
# 3-5 Years      434
# 6-10 Years     448
# 11-20 Years    180
# 21+ Years       66
# Name: count, dtype: int64

# %%
df["YearsAtCompany"].describe()
# Out:
# count    1470.000000
# mean        7.008163
# std         6.126525
# min         0.000000
# 25%         3.000000
# 50%         5.000000
# 75%         9.000000
# max        40.000000
# Name: YearsAtCompany, dtype: float64

# %%
#DISTANCE FROM HOME WISE ATTRITION#
plt.figure(figsize=(8,5))

sns.countplot(
    data=df,
    x="DistanceGroup",
    hue="Attrition"
)

plt.title("Employee Attrition by Distance From Home", fontsize=14)
plt.xlabel("Distance From Home")
plt.ylabel("Number of Employees")
plt.grid(axis="y", linestyle="--", alpha=0.5)

plt.show()

# %%
distance_attrition = pd.crosstab(
    df["DistanceGroup"],
    df["Attrition"],
    normalize="index"
) * 100

distance_attrition = distance_attrition.round(2)

distance_attrition
# Out:
# Attrition         No    Yes
# DistanceGroup
# 1-5 km         86.23  13.77
# 6-10 km        85.53  14.47
# 11-20 km       80.00  20.00
# 21-30 km       77.94  22.06

# %%
df["DistanceGroup"] = pd.cut(
    df["DistanceFromHome"],
    bins=[0,5,10,20,30],
    labels=["1-5 km","6-10 km","11-20 km","21-30 km"]
)

df["DistanceGroup"].value_counts()
# Out:
# DistanceGroup
# 1-5 km      632
# 6-10 km     394
# 11-20 km    240
# 21-30 km    204
# Name: count, dtype: int64

# %%
df["DistanceFromHome"].describe()
# Out:
# count    1470.000000
# mean        9.192517
# std         8.106864
# min         1.000000
# 25%         2.000000
# 50%         7.000000
# 75%        14.000000
# max        29.000000
# Name: DistanceFromHome, dtype: float64

# %%
#JOB INVOLVEMENT WISE ATTRITION#
plt.figure(figsize=(8,5))

sns.countplot(
    data=df,
    x="JobInvolvement",
    hue="Attrition"
)

plt.title("Employee Attrition by Job Involvement", fontsize=14)
plt.xlabel("Job Involvement")
plt.ylabel("Number of Employees")
plt.grid(axis="y", linestyle="--", alpha=0.5)

plt.show()

# %%
jobinvolvement_attrition = pd.crosstab(
    df["JobInvolvement"],
    df["Attrition"],
    normalize="index"
) * 100

jobinvolvement_attrition = jobinvolvement_attrition.round(2)

jobinvolvement_attrition
# Out:
# Attrition          No    Yes
# JobInvolvement
# 1               66.27  33.73
# 2               81.07  18.93
# 3               85.60  14.40
# 4               90.97   9.03

# %%
df["JobInvolvement"].value_counts().sort_index()
# Out:
# JobInvolvement
# 1     83
# 2    375
# 3    868
# 4    144
# Name: count, dtype: int64

# %%
#MARITAL STATUS WISE ATTRITION#
plt.figure(figsize=(8,5))

sns.countplot(
    data=df,
    x="MaritalStatus",
    hue="Attrition"
)

plt.title("Employee Attrition by Marital Status", fontsize=14)
plt.xlabel("Marital Status")
plt.ylabel("Number of Employees")
plt.grid(axis="y", linestyle="--", alpha=0.5)

plt.show()

# %%
marital_attrition = pd.crosstab(
    df["MaritalStatus"],
    df["Attrition"],
    normalize="index"
) * 100

marital_attrition = marital_attrition.round(2)

marital_attrition
# Out:
# Attrition         No    Yes
# MaritalStatus
# Divorced       89.91  10.09
# Married        87.52  12.48
# Single         74.47  25.53

# %%
df["MaritalStatus"].value_counts()
# Out:
# MaritalStatus
# Married     673
# Single      470
# Divorced    327
# Name: count, dtype: int64

# %%
#BUSINESS TRAVEL WISE ATTRITION#
plt.figure(figsize=(8,5))

sns.countplot(
    data=df,
    x="BusinessTravel",
    hue="Attrition"
)

plt.title("Employee Attrition by Business Travel", fontsize=14)
plt.xlabel("Business Travel")
plt.ylabel("Number of Employees")
plt.grid(axis="y", linestyle="--", alpha=0.5)

plt.show()

# %%
businesstravel_attrition = pd.crosstab(
    df["BusinessTravel"],
    df["Attrition"],
    normalize="index"
) * 100

businesstravel_attrition = businesstravel_attrition.round(2)

businesstravel_attrition
# Out:
# Attrition             No    Yes
# BusinessTravel
# Non-Travel         92.00   8.00
# Travel_Frequently  75.09  24.91
# Travel_Rarely      85.04  14.96

# %%
df["BusinessTravel"].value_counts()
# Out:
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64

# %%
#WORK LIFE BALANCE WISE ATTRITION#
plt.figure(figsize=(8,5))

sns.countplot(
    data=df,
    x="WorkLifeBalance",
    hue="Attrition"
)

plt.title("Employee Attrition by Work-Life Balance", fontsize=14)
plt.xlabel("Work-Life Balance")
plt.ylabel("Number of Employees")
plt.grid(axis="y", linestyle="--", alpha=0.5)

plt.show()

# %%
worklife_attrition = pd.crosstab(
    df["WorkLifeBalance"],
    df["Attrition"],
    normalize="index"
) * 100

worklife_attrition = worklife_attrition.round(2)

worklife_attrition
# Out:
# Attrition           No    Yes
# WorkLifeBalance
# 1                68.75  31.25
# 2                83.14  16.86
# 3                85.78  14.22
# 4                82.35  17.65

# %%
df["WorkLifeBalance"].value_counts().sort_index()
# Out:
# WorkLifeBalance
# 1     80
# 2    344
# 3    893
# 4    153
# Name: count, dtype: int64

# %%
#ENVIRONMENT SATISFACTION WISE ATTRITION#
plt.figure(figsize=(8,5))

sns.countplot(
    data=df,
    x="EnvironmentSatisfaction",
    hue="Attrition"
)

plt.title("Employee Attrition by Environment Satisfaction", fontsize=14)
plt.xlabel("Environment Satisfaction")
plt.ylabel("Number of Employees")
plt.grid(axis="y", linestyle="--", alpha=0.5)

plt.show()

# %%
env_attrition = pd.crosstab(
    df["EnvironmentSatisfaction"],
    df["Attrition"],
    normalize="index"
) * 100

env_attrition = env_attrition.round(2)
env_attrition
# Out:
# Attrition                   No    Yes
# EnvironmentSatisfaction
# 1                        74.65  25.35
# 2                        85.02  14.98
# 3                        86.31  13.69
# 4                        86.55  13.45

# %%
df["EnvironmentSatisfaction"].value_counts().sort_index()
# Out:
# EnvironmentSatisfaction
# 1    284
# 2    287
# 3    453
# 4    446
# Name: count, dtype: int64

# %%
#JOB SATISFACTION WISE ATTRITION#
plt.figure(figsize=(8,5))

sns.countplot(
    data=df,
    x="JobSatisfaction",
    hue="Attrition"
)

plt.title("Employee Attrition by Job Satisfaction", fontsize=14)
plt.xlabel("Job Satisfaction")
plt.ylabel("Number of Employees")
plt.grid(axis="y", linestyle="--", alpha=0.5)

plt.show()

# %%
job_sat_attrition = pd.crosstab(
    df["JobSatisfaction"],
    df["Attrition"],
    normalize="index"
) * 100

job_sat_attrition = job_sat_attrition.round(2)
job_sat_attrition
# Out:
# Attrition           No    Yes
# JobSatisfaction
# 1                77.16  22.84
# 2                83.57  16.43
# 3                83.48  16.52
# 4                88.67  11.33

# %%
df["JobSatisfaction"].value_counts().sort_index()
# Out:
# JobSatisfaction
# 1    289
# 2    280
# 3    442
# 4    459
# Name: count, dtype: int64

# %%
#MONTHLY INCOME WISE ATTRITION#
monthlyincome_attrition = pd.crosstab(
    df["MonthlyIncome"],
    df["Attrition"],
    normalize="index"
) * 100

monthlyincome_attrition = monthlyincome_attrition.round(2)

monthlyincome_attrition
# Out:
# Attrition         No    Yes
# MonthlyIncome
# 1009             0.0  100.0
# 1051           100.0    0.0
# 1052           100.0    0.0
# 1081             0.0  100.0
# 1091             0.0  100.0
# ...              ...    ...
# 19859            0.0  100.0
# 19926          100.0    0.0
# 19943          100.0    0.0
# 19973          100.0    0.0
# 19999          100.0    0.0
#
# [1349 rows x 2 columns]

# %%
plt.figure(figsize=(8,5))

sns.boxplot(data=df, x="Attrition", y="MonthlyIncome")

plt.title("Monthly Income vs Attrition", fontsize=14)
plt.xlabel("Attrition")
plt.ylabel("Monthly Income")

plt.grid(axis="y", linestyle="--", alpha=0.5)

plt.show()

# %%
#OVERTIME  WISE ATTRITION#
plt.figure(figsize=(6,4))

sns.countplot(
    data=df,
    x="OverTime",
    hue="Attrition"
)

plt.title("Employee Attrition by OverTime", fontsize=14)
plt.xlabel("OverTime")
plt.ylabel("Number of Employees")

plt.grid(axis="y", linestyle="--", alpha=0.5)

plt.show()

# %%
overtime_attrition = pd.crosstab(
    df["OverTime"],
    df["Attrition"],
    normalize="index"
) * 100

overtime_attrition = overtime_attrition.round(2)

overtime_attrition
# Out:
# Attrition     No    Yes
# OverTime
# No         89.56  10.44
# Yes        69.47  30.53

# %%
df["OverTime"].value_counts()
# Out:
# OverTime
# No     1054
# Yes     416
# Name: count, dtype: int64

# %%
#JOB ROLE WISE ATTRITION#
jobrole_attrition = pd.crosstab(
    df["JobRole"],
    df["Attrition"],
    normalize="index"
)*100

jobrole_attrition = jobrole_attrition.round(2)
jobrole_attrition
# Out:
# Attrition                     No    Yes
# JobRole
# Healthcare Representative  93.13   6.87
# Human Resources            76.92  23.08
# Laboratory Technician      76.06  23.94
# Manager                    95.10   4.90
# Manufacturing Director     93.10   6.90
# Research Director          97.50   2.50
# Research Scientist         83.90  16.10
# Sales Executive            82.52  17.48
# Sales Representative       60.24  39.76

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=df, x="JobRole", hue="Attrition")
plt.title("Employee Attrition by Job Role", fontsize=14)
plt.xlabel("Job Role")
plt.ylabel("Number of Employees")
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.5)
plt.show()

# %%
df["JobRole"].value_counts()
# Out:
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64

# %%
#AGE WISE ATTRITION#
age_attrition = pd.crosstab(
    df["AgeGroup"],
    df["Attrition"],
    normalize="index"
)*100

age_attrition = age_attrition.round(2)
age_attrition
# Out:
# Attrition     No    Yes
# AgeGroup
# 18-25      65.22  34.78
# 26-35      80.86  19.14
# 36-45      90.81   9.19
# 46-60      87.55  12.45

# %%
df["AgeGroup"] = pd.cut(
    df["Age"],
    bins=[18,25,35,45,60],
    labels=["18-25", "26-35", "36-45", "46-60"]
)

df["AgeGroup"].value_counts()
# Out:
# AgeGroup
# 26-35    606
# 36-45    468
# 46-60    273
# 18-25    115
# Name: count, dtype: int64

# %%
age_attrition = pd.crosstab(
    df["Age"],
    df["Attrition"],
    normalize="index"
)*100

age_attrition = age_attrition.round(2)
age_attrition
# Out:
# Attrition      No    Yes
# Age
# 18          50.00  50.00
# 19          33.33  66.67
# 20          45.45  54.55
# 21          53.85  46.15
# 22          68.75  31.25
# 23          71.43  28.57
# 24          73.08  26.92
# 25          76.92  23.08
# 26          69.23  30.77
# 27          93.75   6.25
# 28          70.83  29.17
# 29          73.53  26.47
# 30          85.00  15.00
# 31          73.91  26.09
# 32          81.97  18.03
# 33          79.31  20.69
# 34          88.31  11.69
# 35          87.18  12.82
# 36          91.30   8.70
# 37          88.00  12.00
# 38          96.55   3.45
# 39          85.71  14.29
# 40          91.23   8.77
# 41          85.00  15.00
# 42          95.65   4.35
# 43          93.75   6.25
# 44          81.82  18.18
# 45          95.12   4.88
# 46          87.88  12.12
# 47          87.50  12.50
# 48          89.47  10.53
# 49          91.67   8.33
# 50          83.33  16.67
# 51          89.47  10.53
# 52          83.33  16.67
# ...

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["Age"], bins=15, kde=True)
plt.title("Age Distribution of Employee", fontsize=14)
plt.xlabel("Age")
plt.ylabel("Number of Employees")
plt.grid(axis="y", linestyle="--", alpha=0.5)
plt.show()

# %%
#GENDER WISE ATTRITION#
gender_attrition = pd.crosstab(
    df["Gender"],
    df["Attrition"],
    normalize="index"
)*100

gender_attrition = gender_attrition.round(2)
gender_attrition
# Out:
# Attrition     No    Yes
# Gender
# Female     85.20  14.80
# Male       82.99  17.01

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df, x="Gender", hue="Attrition")
plt.title("Employee Attrition by Gender", fontsize=14)
plt.xlabel("Gender")
plt.ylabel("Number of Employees")
plt.grid(axis="y", linestyle="--", alpha=0.5)
plt.show()

# %%
#DEPARTMENT WISE ATTRITION#
dept_attrition = pd.crosstab(
    df["Department"],
    df["Attrition"],
    normalize="index"
)*100

dept_attrition = dept_attrition.round(2)
dept_attrition
# Out:
# Attrition                  No    Yes
# Department
# Human Resources         80.95  19.05
# Research & Development  86.16  13.84
# Sales                   79.37  20.63

# %%
df["Department"].value_counts()
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df, x="Department", hue="Attrition")
plt.title("Employee Distribution by Department", fontsize=14)
plt.xlabel("Department")
plt.ylabel("Number of Employees")
plt.grid(axis="y", linestyle="--", alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df, x="Department")
plt.title("Employee Distribution by Department", fontsize=14)
plt.xlabel("Department")
plt.ylabel("Number of Employees")
plt.grid(axis="y", linestyle="--", alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="Attrition", hue="Attrition", legend=False)
plt.title("Employee Attrition Count", fontsize=14)
plt.xlabel("Attrition")
plt.ylabel("Number of Employees")
plt.grid(axis="y", linestyle="--", alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="Attrition")
plt.title("Employee Attrition Count")
plt.show()

# %%
#ATTRITION PERCENTAGE#
attrition = df["Attrition"].value_counts()
attrition_percent = round((attrition / len(df)) * 100,2)
print(attrition_percent)
# Out:
# Attrition
# No     83.88
# Yes    16.12
# Name: count, dtype: float64

# %%
df["Attrition"].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
df.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %%
df.duplicated() .sum()
# Out:
# np.int64(0)

# %%
df.isnull() .sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   str
#  2   BusinessTravel            1470 non-null   str
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   str
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   str
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   str
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='str')

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df = pd.read_csv("RAW/WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
# Importing required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# # HR Analytics - Employee Attrition Analysis
#
# ## Objective
#
# The objective of this project is to analyze employee attrition data and identify the factors affecting employee turnover.
#
# ## Tools Used
#
# - Python
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn
#
# ## Dataset
#
# IBM HR Analytics Employee Attrition Dataset
